# %%
from src.generator import generate_feature_store_data, generate_fraud_labels

# %%
feature_store = (
    generate_feature_store_data(spark)
        .transform(generate_fraud_labels)
)

# %%
display(feature_store)

# %%
feature_store.write.format("delta").mode("append").saveAsTable("main.feature_store.online_transactions")
